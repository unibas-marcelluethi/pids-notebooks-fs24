# %% [markdown]
# # Practice exam - PiDS 2024. Time: 45 Minutes

# %% [markdown]
# Marcel Lüthi, marcel.luethi@unibas.ch

# %% [markdown]
# ## Theory (20 Points)

# %% [markdown]
# ### Question 1: Libraries (3 Points)
#
# Which library would we use for the following use cases?
#
# 1) Reading and manipulating tabular data
# 2) Learning a machine learning model
# 3) Generate a matrix of uniform  random numbers
#
# Write your answer in the following dictionary.

# %%
q1 = {
    1 : "Pandas",
    2 : "Scikit-learn",
    3 : "numpy"
}

# %% [markdown]
# ### Question 2: Tidy data (2 Points)
# ![grafik-2.png](attachment:grafik-2.png)
#
# This dataset is not considered to be tidy. Why?

# %%
q2 = "income should be a variable and not having values in different fields"

# %% [markdown]
# ### Question 3:  Distributions (1 Point)
#
# Based on some samples $X$, we obtain the following figure. From which distribution was $X$ most likely generated?
#
# ![grafik.png](attachment:grafik.png)
#
# 1. A Bernoulli distribution `bernoulli(p=0.5)`
# 2. A Binomial distribution `binom(n=10, p=0.5)`
# 3. A Poisson distribution `poisson(mu=3)`
# 4. A Normal distribution `normal(5, 4)`

# %%
q3 = 2 # Replace 0 with 1, 2 or 3

# %% [markdown]
# ### Question 4: More distributions (2 Points)
#
# Assume we generated $N$ batches of 100 Bernoulli random variables. Let us denote the m-th variable in the n-th batch by $X_{mn}$. We then computed the means of all batches to obtain $X_n=\frac{1}{100} \sum_{m=1}^{100}X_{mn}$. Which of the following statements about the mean and the variance of $X_n$ are true?
#
# 1. The Mean of the random variable $X_n$ is 0 and variance is 1
# 2. The Mean and/or variance depend on the number of experiment N
# 3. The Mean and/or variance depend on the number of element in the empirical mean (here 100)
# 4. The Mean and/or variance depend on the parameter of the Bernoulli distribution (here p=0.5)

# %%
q4 = [2, 3, 4] # remove all the answers that don't apply

# %% [markdown]
# ### Question 5 (1 Point)
#
# Let us simulate a game of 1000 coin tosses by generating 1000 Bernoulli random variables
# ${X1, , XN}$ with $N=1000$. The theoretical mean of these random variables is $0.5$ and the theoretical  variance is $0.25$. We compute the empirical mean of the observations  $X=\frac{1}/{1000} \sum_{n=1}^{1000} X_n$ and obtain  $X=0.483$. We are wondering if the true mean is indeed 0.5. Following the lectures, we compute the asymptotic $95\%$ confidence interval around the true mean (using central limit theorem approximation) by using the formula:
# $I=[\overline{X} - 1.96 \frac{\sqrt{0.25}}{Y},\overline{X} + 1.96\frac{\sqrt{0.25}}{Y}]$.
#
# What is the correct value Y?
#
# 1. $N$
# 2. $\sqrt{N}$
# 3. $N^2$

# %%
q5 = 2 # Replace 0 with 1, 2 or 3

# %% [markdown]
# ### Question 6: Encoding (2 Points)
#
# Assume we have the following dataset.
#
# |Job | Age | Income |
# |----|-----|--------|
# |Plumber | 25 | 50'000|
# |Joiner | 55 | 55'000|
# |Joiner | 20 | 40'000|
# |Butcher | 40 | 45'000|
#
# In order to train a regression model, we replace the non-numerical data with the following numerical values.
#
# |Job | Age | Income |
# |----|-----|--------|
# |1 | 25 | 50'000|
# |2 | 55 | 55'000|
# |2 | 20 | 40'000|
# |3 | 40 | 45'000|
#
# What could be a problem with this approach?

# %%
q6 = "Values introduce a notion of closeness between different jobs, which is arbitrary"

# %% [markdown]
# ### Question 7: (1 Point)
#
# ![grafik.png](attachment:grafik.png)
#
# Which of the two figures is preferable to visualize the the market shares of each browser?
#
# 1. Pie chart
# 2. Bar plot
# 3. None of the above, a plot with a linear regression would have been better

# %%
q7 = 2 # Replace 0 with 1, 2 or 3

# %% [markdown]
# ### Question 8: Regression (1 Point)
#
# Which of the following metrics can be used to assess how well a regression model fits the data.
#
# 1. r2 score
# 2. precision
# 3. recall
# 4. area under the curve

# %%
q8 = 1 # Replace 0 with 1, 2 or 3

# %% [markdown]
# ### Question 9: Training a machine learning model (2 + 2 Points)
#
# Explain in 1 sentence what overfitting is provide one measure that guards against it.

# %%
q9_overfitting = "The model fits not only the pattern but also the noise in the data"
q9_guards = "Validate performance on a separate validation and/or test set. "

# %% [markdown]
# ### Question 10: Convergence (1 Point)
#
# Which theorem explains why the average of a large number of observations from any distribution will be approximately normal?
#
# 1. Law of Large Numbers
# 2. Central Limit Theorem
# 3. Bayes' Theorem
# 4. Law of total probability

# %%
q10 = 2  # Replace 0 with 1, 2, 3 or 4

# %% [markdown]
# ### Question 11: Bootstrapping (2 Points)
#
# Write down two problems in statistics for which applying bootstrapping provides a useful solution.

# %%
q11_1 = "Estimating confidence intervals"
q11_2 = "Estimating the standard error"

# %% [markdown]
# # Practice (20 Points)

# %% [markdown]
# Let's load some libraries:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# In the following we work with the titanic dataset.

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Question 12: Plotting (4 Points)
#
# Create a scatter plot that plots "age" agains "fare". You can choose whatever plotting tool you prefer.
#
# API Documentation:
# * [pandas](https://pandas.pydata.org/docs/reference/index.html#api)
# * [matplotlib](https://matplotlib.org/stable/api/index.html)
# * [seaborn](https://seaborn.pydata.org/api.html).

# %%
# Your answer
plot = df.plot.scatter("age", "fare")

# %% [markdown]
# ### Question 13: Select values (4 Points)
#
# Select all the rows where the variable `sex` is female and `age` is greater than 20.

# %%
woman_over_20 = df[(df["sex"] == "female") & (df["age"] > 20)]

# %% [markdown]
# ### Question 14: Summary statistics (6 Points)
#
# Add a new column column `fare_normalized`, that contains standardized values of fare, by subtracting the mean and dividing by the standard deviation.

# %%
fare_mean = df["fare"].mean()
fare_stddev = df["fare"].std()
df["fare_normalized"] = (df["fare"] - fare_mean)/fare_stddev
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  fare_normalized
# 0    man        True  NaN  Southampton    no  False        -0.502163
# 1  woman       False    C    Cherbourg   yes  False         0.786404
# 2  woman       False  NaN  Southampton   yes   True        -0.488580
# 3  woman       False    C  Southampton   yes  False         0.420494
# 4    man        True  NaN  Southampton    no   True        -0.486064

# %% [markdown]
# ### Question 15: Train a classifier (6 Points)
#
# Use scikit learn to train a neural network predicting the survival (column `survived`) from the column
# `age` `fare` and `pClass`. Use 2 hidden layers with 10 neurons each. You don't need to preprocess or scale any variables, but you should drop all the nan values from the dataset.
#
# You can access the documentation of scikit learn here:
# * [scikit learn api doc](https://scikit-learn.org/stable/api/index.html)

# %%
df_nonan = df.dropna()
X = df_nonan[["age", "fare", "pclass"]]
y = df_nonan["survived"]
cls = MLPClassifier(hidden_layer_sizes=[10, 10])
cls.fit(X, y)
# Out:
# MLPClassifier(hidden_layer_sizes=[10, 10])

# %% [markdown]
# ### Question 16: Conditional probability (4 Points)
#
# Estimate the condional probability of surviving given that `sex` is `female`.
#
# **Reminder:** the conditional probability is defined as:
# $$ \mathbb{P}(A|B) = \frac{\mathbb{P}(A \cap B)}{\mathbb{P}(B)}$$

# %%
p_female = len(df[df["sex"] == "female"])/len(df)
p_female_survived = len(df[(df["sex"] == "female") & (df["survived"] == 1)])/len(df)

print(p_female_survived / p_female)
prob = ... # your answer
# Out:
# 0.7420382165605095
