# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100
import seaborn as sns
sns.set_style("whitegrid")
import pandas as pd
import random
import numpy as np

# %%
# Tossing a coin 

import random

n_games = 1000
n_tosses = 100

tails_per_game = []
for i_game in range(n_games):
    n_tails = 0
    for i in range(n_tosses):
        toss = random.randint(0, 1)
        n_tails += 1 if toss == 0 else 0
    tails_per_game.append(n_tails)
        
sns.histplot(tails_per_game)

print(tails_per_game[0] / n_tosses)
# Out:
# 0.46

# %%
# Rolling a die

import random

n_games = 100
n_rolls = 100

fours_per_game = []
for i_game in range(n_games):
    n_fours = 0
    for i in range(n_rolls):
        roll = random.randint(1, 6)
        n_fours += 1 if roll == 4 else 0
    fours_per_game.append(n_fours)
        
sns.histplot(fours_per_game)
# Out:
# <Axes: ylabel='Count'>

# %%
# Handedness

population_size = 100
n_studies = 1000
prob_left_handed = 0.2

n_lefthanded = 0
n_lefthanded_per_study = []

for i_game in range(n_studies):
    n_lefthanded = 0

    for i in range(population_size):
        if random.uniform(0, 1) < prob_left_handed:
            n_lefthanded += 1 
    n_lefthanded_per_study.append(n_lefthanded)
        
sns.histplot(n_lefthanded_per_study)
# Out:
# <Axes: ylabel='Count'>
